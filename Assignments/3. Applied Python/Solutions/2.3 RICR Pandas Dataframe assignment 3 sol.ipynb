# %%
import pandas as pd

# %%
df = pd.read_csv("Titanic Dataset.csv")

# %%
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 355         1247         0       1  Julian, Mr. Henry Forbes    male  50.0
# 393         1285         0       2      Gilbert, Mr. William    male  47.0
# 231         1123         1       1  Willard, Miss. Constance  female  21.0
#
#      SibSp  Parch      Ticket   Fare Cabin Embarked  Title  FamilySize  \
# 355      0      0      113044  26.00   E60        S    Mr.           0
# 393      0      0  C.A. 30769  10.50   NaN        S    Mr.           0
# 231      0      0      113795  26.55   NaN        S  Miss.           0
#
#      FarePerPerson
# 355       0.038462
# 393       0.095238
# 231       0.037665

# %% [markdown]
# 1. Display the names of all passengers who paid a fare greater than
# $100 and were under the age of 30.

# %%
selected_passengers = df[(df['Fare']>100)&(df['Age']<30)]
names=selected_passengers['Name']
names
# Out:
# 53                            Fortune, Miss. Ethel Flora
# 64                           Ryerson, Master. John Borie
# 156                                    Bird, Miss. Ellen
# 184    Douglas, Mrs. Frederick Charles (Mary Helene B...
# 196                      Spedden, Master. Robert Douglas
# 252                             Clark, Mr. Walter Miller
# 272        Clark, Mrs. Walter Miller (Virginia McDowell)
# Name: Name, dtype: object

# %% [markdown]
# 2. Find the top 5 oldest passengers. What are their names, ages, and
# whether they survived?

# %%
sltd_pass=df.sort_values(by='Age',ascending=False).head(5)
sltd_pass[['Name','Age','Survived']]
# Out:
#                                                   Name   Age  Survived
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  76.0         1
# 81                                  Straus, Mr. Isidor  67.0         0
# 236                           Warren, Mr. Frank Manley  64.0         0
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  64.0         1
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  64.0         1

# %% [markdown]
# 3. Count how many passengers have a missing value for their cabin
# number (Cabin).

# %%
n = df['Cabin'].isna().sum()
print(n)
# Out:
# 327

# %% [markdown]
# 4. Extract and create a new column called 'Title' from the 'Name' column (e.g., Mr., Mrs., Miss, etc.). After creating the column, display the first 5 unique titles.

# %%
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 240         1132         1       1  Lindstrom, Mrs. Carl Johan (Sigrid Posse)
# 318         1210         0       3                  Jonsson, Mr. Nils Hilding
# 333         1225         1       3      Nakid, Mrs. Said (Waika Mary" Mowad)"
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked Title  \
# 240  female  55.0      0      0  112377  27.7208   NaN        C  Mrs.
# 318    male  27.0      0      0  350408   7.8542   NaN        S   Mr.
# 333  female  19.0      1      1    2653  15.7417   NaN        C  Mrs.
#
#      FamilySize  FarePerPerson
# 240           0       0.036074
# 318           0       0.127320
# 333           2       0.190577

# %%
df['Title'] = df['Name'].str.split(',').str.get(1).str.strip().str.split().str.get(0)
df['Title'].unique()[:5]
# Out:
# array(['Mr.', 'Mrs.', 'Miss.', 'Master.', 'Ms.'], dtype=object)

# %% [markdown]
# 5. Identify all passengers whose age is missing (NaN). Replace the missing age values with the average age of all passengers in the dataset.

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df['Age'].isna().sum()
# Out:
# C:\Users\anike\AppData\Local\Temp\ipykernel_23872\2663981579.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)
# np.int64(0)

# %% [markdown]
# 6. Sort the dataset based on fare in descending order and display the
# top 10 passengers with the highest fares.

# %%
df['Fare'].sort_values(ascending=False).head(10)
# Out:
# 343    512.3292
# 69     263.0000
# 53     263.0000
# 59     262.3750
# 64     262.3750
# 375    262.3750
# 142    262.3750
# 24     262.3750
# 184    247.5208
# 202    227.5250
# Name: Fare, dtype: float64

# %% [markdown]
# 7. Find the name of the youngest passenger who did not survive.

# %%
ndf = df[df['Survived']==0]
ndf.loc[ndf['Age'].idxmin(),'Name']
# Out:
# 'Danbom, Master. Gilbert Sigvard Emanuel'

# %% [markdown]
# 8. Display the first 5 rows where the passenger's name starts with
# the letter 'A'

# %%
df[df['Name'].str.get(0) == 'A'].head(5)
# Out:
#     PassengerId  Survived  Pclass                                       Name  \
# 8           900         1       3  Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 17          909         0       3                          Assaf, Mr. Gerios
# 19          911         1       3      Assaf Khalil, Mrs. Mariana (Miriam")"
# 57          949         0       3              Abelseth, Mr. Olaus Jorgensen
# 78          970         0       2             Aldworth, Mr. Charles Augustus
#
#        Sex   Age  SibSp  Parch  Ticket     Fare  Cabin Embarked Title  \
# 8   female  18.0      0      0    2657   7.2292    NaN        C  Mrs.
# 17    male  21.0      0      0    2692   7.2250    NaN        C   Mr.
# 19  female  45.0      0      0    2696   7.2250    NaN        C  Mrs.
# 57    male  25.0      0      0  348122   7.6500  F G63        S   Mr.
# 78    male  30.0      0      0  248744  13.0000    NaN        S   Mr.
#
#     FamilySize  FarePerPerson
# 8            0       0.138328
# ...

# %% [markdown]
# 9. Create a new column called ‘FamilySize’, which is the sum of
# 'SibSp' and 'Parch'. Then, display the first 10 rows where the
# family size is greater than 3.

# %%
df['FamilySize'] = df['SibSp'] + df['Parch']
df[(df['FamilySize']>3)].head(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 24           916         1       1
# 53           945         1       1
# 55           947         0       3
# 64           956         0       1
# 69           961         1       1
# 132         1024         1       3
# 139         1031         0       3
# 140         1032         1       3
# 142         1034         0       1
# 154         1046         0       3
#
#                                                 Name     Sex       Age  SibSp  \
# 24   Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.00000      1
# 53                        Fortune, Miss. Ethel Flora  female  28.00000      3
# 55                              Rice, Master. Albert    male  10.00000      4
# 64                       Ryerson, Master. John Borie    male  13.00000      2
# 69               Fortune, Mrs. Mark (Mary McDougald)  female  60.00000      1
# 132                    Lefebre, Mrs. Frank (Frances)  female  30.27259      0
# ...

# %% [markdown]
# 10. Create a new column ‘FarePerPerson’ by dividing the 'Fare' by the sum of 'SibSp' + 'Parch' + 1 (to account for the passenger themselves). Then, find the highest ‘FarePerPerson’ and display the name and fare of that passenger.

# %%
df['FarePerPerson']=(df['Fare'])/(df['FamilySize']+1)
df[df['FarePerPerson'] ==  df['FarePerPerson'].max()][['Name','FarePerPerson']]
# Out:
#                             Name  FarePerPerson
# 59   Chaudanson, Miss. Victorine        262.375
# 375     Bowen, Miss. Grace Scott        262.375
