# %% [markdown]
# # MATRIX PLOTS
# ![Screenshot 2024-07-10 180301.png](data:image/png;base64,...)

# %% [markdown]
# ## Seaborn: Matrix Plots
#
# ### What are Matrix Plots?
#
# - **Matrix Plots**: Visualizations that show data in a grid format.
# - **Each cell in the grid** represents a data point.
#
# ### Why Use Matrix Plots?
#
# - To easily see **patterns, relationships, and anomalies** in data.
# - Useful for **comparing multiple variables**.
#
# ### What Do They Show?
#
# - **Heatmaps**: Color-coded representation of data.
# - **Cluster Maps**: Heatmaps with hierarchical clustering.
#
# ### When to Use Matrix Plots?
#
# - When you need to **visualize relationships** between multiple variables.
# - For **correlation matrices**, **feature comparisons**, and **pattern recognition**.

# %%
import seaborn as sns

# %% [markdown]
# ## Type of data :
# 1. Numerical data
# 2. Categorical data.

# %%
df = sns.load_dataset('penguins')

# %%
df.sample(6)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 225     Gentoo     Biscoe            46.5           13.5              210.0
# 38      Adelie      Dream            37.6           19.3              181.0
# 75      Adelie  Torgersen            42.8           18.5              195.0
# 47      Adelie      Dream            37.5           18.9              179.0
# 45      Adelie      Dream            39.6           18.8              190.0
# 181  Chinstrap      Dream            52.8           20.0              205.0
#
#      body_mass_g     sex
# 225       4550.0  Female
# 38        3300.0  Female
# 75        4250.0    Male
# 47        2975.0     NaN
# 45        4600.0    Male
# 181       4550.0    Male

# %% [markdown]
# ## Heatmap()

# %%
# Calculate correlation matrix
correlation_matrix = df.corr(numeric_only=True)

# Heatmap
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %% [markdown]
# ## Parameters ->
# 1. annot = True

# %%
sns.heatmap(correlation_matrix , annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Parameter ->
# 4. fmt=".1f",  Format values to two decimal places

# %%
sns.heatmap(correlation_matrix , annot = True, fmt = '.1f')
# Out:
# <Axes: >

# %% [markdown]
# ## Parameter->
# 2. linewidth and linecolor.

# %%
sns.heatmap(correlation_matrix , annot = True, linewidths=2, linecolor="m" )
# Out:
# <Axes: >

# %% [markdown]
# ## Parameter ->
# 3. cmap = 'viridis' or 'summer' or 'winter' or 'jet' or 'coolwarm'

# %%
sns.heatmap(correlation_matrix,annot = True,linewidth = 2,cmap = 'coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## clustermap()

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# Prepare the data for clustering
# Selecting numerical columns only
numeric_data = df.select_dtypes(include=["float", "int"]).dropna()

# Clustermap
sns.clustermap(
    numeric_data.corr(),  # Correlation matrix as input
    method="complete",  # Hierarchical clustering method (e.g., single, complete, average)
    cmap="coolwarm",  # Color map
    annot=True,  # Show values in cells
    figsize=(10, 8)  # Adjust figure size
)

# %% [markdown]
# ### Pairplot.

# %%
sns.pairplot(df)

# %%
# hue
sns.pairplot(data=df, hue="species")

# %% [markdown]
# -> palette parameter : Change color schemes
#  = {"viridis", "Set2", "plasma", "coolwarm"}

# %%
# palette
sns.pairplot(data=df, hue="species",palette="Set2")

# %% [markdown]
# -> diag_kind: Choose between "kde" or "hist" for diagonal.

# %%
sns.pairplot(data=df, hue="species", diag_kind="hist", palette="viridis")

# %%
sns.pairplot(data=df, hue="species", markers=["o", "s", "D"], palette="coolwarm")

# %% [markdown]
# -> var : select the columns on which pairplot should be made.

# %%
# var
sns.pairplot(data=df, vars=["bill_length_mm", "bill_depth_mm", "flipper_length_mm"], hue="species")

# %%
# corner=True
sns.pairplot(data=df, hue="species", palette="Set2",corner=True)
